# %%
import pandas as pd

# %%
csv_file = "it_worked.csv"
HAR = pd.read_csv(csv_file)
HAR.head()
# Out:
#    Unnamed: 0     Price                                             Street  \
# 0           0  $135,000  \n                  524 N Jenkins St,\n       ...
# 1           1  $200,000  \n                  14022 Autumn Ridge Trail D...
# 2           2  $145,000  \n                  9506 E Avenue I,\n        ...
# 3           3  $135,000  \n                  524 N Jenkins St,\n       ...
# 4           4  $200,000  \n                  14022 Autumn Ridge Trail D...
#
#    Zip Code     City
# 0     77003  Houston
# 1     77048  Houston
# 2     77012  Houston
# 3     77003  Houston
# 4     77048  Houston

# %%
HAR=HAR.replace('\n','',regex=True)
HAR.head()
# Out:
#    Unnamed: 0     Price                                             Street  \
# 0           0  $135,000                    524 N Jenkins St,           ...
# 1           1  $200,000                    14022 Autumn Ridge Trail Dr,...
# 2           2  $145,000                    9506 E Avenue I,            ...
# 3           3  $135,000                    524 N Jenkins St,           ...
# 4           4  $200,000                    14022 Autumn Ridge Trail Dr,...
#
#    Zip Code     City
# 0     77003  Houston
# 1     77048  Houston
# 2     77012  Houston
# 3     77003  Houston
# 4     77048  Houston

# %%
HAR=HAR.drop('Unnamed: 0',axis=1)
HAR.head()
# Out:
#       Price                                             Street  Zip Code  \
# 0  $135,000                    524 N Jenkins St,           ...     77003
# 1  $200,000                    14022 Autumn Ridge Trail Dr,...     77048
# 2  $145,000                    9506 E Avenue I,            ...     77012
# 3  $135,000                    524 N Jenkins St,           ...     77003
# 4  $200,000                    14022 Autumn Ridge Trail Dr,...     77048
#
#       City
# 0  Houston
# 1  Houston
# 2  Houston
# 3  Houston
# 4  Houston

# %%
HAR.to_csv('HAR.csv')
